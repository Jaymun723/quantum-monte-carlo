# %%
# Première génération d'une grille et affichage avec draw


# %load_ext autoreload
# %autoreload 2
import numpy as np
from production import Problem, ExactSolver, Worldline


rng = np.random.default_rng(seed=7)


pb64 = pb.Problem(6, 1, 1, 1, 4)


# first_grid = ws.Worldline(first_test)


# first_grid.draw()


wl64 = ws.ExhaustiveWorldline(pb64)


wl64.generate_all_wordlines()


print('Worldlines generated:', len(wl64.worldlines))

# %%
pb44 = pb.Problem(4, 1, 1, 1, 4)

# first_grid = ws.Worldline(first_test)

# first_grid.draw()

wl44 = ws.ExhaustiveWorldline(pb44)
wl44.generate_all_wordlines()
len(wl44.worldlines)

# %%
wl4.draw(wl4.worldlines[3500])
# first_grid.draw()

# %%
# for wl in wl4.worldlines:
#     wl4.draw(wl)

# %%
import production.vertex_updates as vu
first_grid = ws.Worldline(first_test)
first_grid._initialize_state()
first_grid.draw()
first_grid.draw_vertices()

# %%
grid = first_grid.copy()

n = 0
visited_vertex = vu.perform_vertex_loop_update(grid, rng)

while visited_vertex is None:
    visited_vertex = vu.perform_vertex_loop_update(grid, rng)
    # print(f"{a} < {delta_Omega}")
    n+=1
# print(visited_vertex)
# print(grid.energy, grid.compute_energy(), first_grid.energy, first_grid.compute_energy())

# grid.draw()
# print(n, a, delta_Omega)
grid.draw_vertices([visited_vertex])

# %%
# grid.draw()
grid.draw_vertices([visited_vertex])

# %%
first_test = pb.Problem( 4, 1, 1, 300, 2.5)
wl4 = ws.ExhaustiveWorldline(first_test)
wl4.generate_all_wordlines()
len(wl4.worldlines)

# %%
print("Number of worldlines generated:", len(wl4.worldlines))
for i in range(len(wl4.worldlines)):
    wl4.draw_worldline(wl4.worldlines[i])

# %%
#Test pour draw avec texte bien situé

first_grid.draw()
